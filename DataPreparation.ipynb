# %%
import pandas as pd
from collections import defaultdict
from os import getcwd

# %%
PATH_1   = f"{getcwd()}/udemy_courses.csv"

# %%
PATH_1
# Out:
# 'c:\\Users\\Vivek Kumar\\OneDrive\\Desktop\\assignment\\Data Store/udemy_courses.csv'

# %%
df=pd.read_csv(PATH_1)
df
# Out:
#       course_id                                       course_title  is_paid  \
# 0          8324                           Javascript for Beginners     True
# 1          8325            HTML Tutorial: HTML & CSS for Beginners     True
# 2         11153     Learn jQuery: An In-depth Course For Beginners     True
# 3         11174                Become a Web Developer from Scratch     True
# 4         11475                   Become a Certified Web Developer     True
# ...         ...                                                ...      ...
# 1086    1262470      Learn Vikings Soundtracks on the Piano by Ear     True
# 1087    1263966  Covered Calls - Powerful Income Strategy for S...     True
# 1088    1264512           Learn JSON for beginners with JavaScript     True
# 1089    1265678       Photoshop Avan?do - P? Produ?o e fus? com 3D    False
# 1090    1265814  Advanced Butterfly Spreads for Options Income ...    False
#
# ...

# %%
print(f"It is {pd.Series(df['course_id']).is_unique}  that the column 'courseid' has unique values for all entries in course dataframe.")
# Out:
# It is True  that the column 'courseid' has unique values for all entries in course dataframe.

# %%
print(f"It is {pd.Series(df['course_title']).is_unique}  that the column 'course_name' has unique values for all entries in course dataframe.")
# Out:
# It is True  that the column 'course_name' has unique values for all entries in course dataframe.

# %%
course_dic = {}
df_name = df['course_title'].tolist()
df_name
# Out:
# ['Javascript for Beginners',
#  'HTML Tutorial: HTML & CSS for Beginners',
#  'Learn jQuery: An In-depth Course For Beginners',
#  'Become a Web Developer from Scratch',
#  'Become a Certified Web Developer',
#  'Back 2 The Basics',
#  'Introduction to Java Programming for Online Learners',
#  'Aprende a Tocar Teclado - Piano',
#  'Learn HTML5 At Your Own Pace. Ideal for Beginners',
#  'HTML Workshop',
#  'Learn To Draw - The COMIC BOOK STYLE',
#  'Discover the 7 Secrets to Figure Drawing: Draw Awesome ...',
#  'AJAX Development',
#  'Web Programming with Python',
#  'Drawing With Confidence',
#  'Color Basics for Print Designers',
#  'Figure Drawing From Life Using The Reilly Technique.',
#  'JavaScript with BackboneJS and Bootstrap CSS - Advanced',
#  'Play Ukulele Now',
#  'Learning CSS3 - A Comprehensive Tutorial For Web Developers',
#  'Graphic Design Secrets Revealed',
#  'Create an Engaging Website with Twitter Bootstrap 2.x',
#  'The Original Complete Web Developer Course.',
# ...

# %%
x = 1
for i in df_name:
    course_dic[i] = x
    x=x+1
print(course_dic)

# %%
df.iloc[0,4]
# Out:
# 3697

# %%
df_name1 = {}
x =0
for i in df_name:
    df_name1[x] ={
        'course_id':df.iloc[x,0],
        'course_title': df.iloc[x,1],
        'is_paid':df.iloc[x,2],
       'price':df.iloc[x,3],
        'num_subscribers':df.iloc[x,4],
        'num_lectures':df.iloc[x,5],
        'content_duration':df.iloc[x,6],
        'published_timestamp':df.iloc[x,7],
        'subject':df.iloc[x,8]

    }
    x+=1

# %%
df_name1

# %%
# %store course_dic
# %store df_name1
# Out:
# Stored 'course_dic' (dict)
# Stored 'df_name1' (dict)
